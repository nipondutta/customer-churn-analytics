# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay,
    RocCurveDisplay
)

# %%
df = pd.read_csv("../data/processed/customers_features.csv")

df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... MonthlyCharges  \
# 0  No phone service             DSL             No  ...          29.85
# 1                No             DSL            Yes  ...          56.95
# 2                No             DSL            Yes  ...          53.85
# 3  No phone service             DSL            Yes  ...          42.30
# 4                No     Fiber optic             No  ...          70.70
#
#   TotalCharges Churn   TenureGroup SeniorCitizenLabel ChurnFlag  \
# ...

# %%
df["ChurnFlag"].value_counts()
# Out:
# ChurnFlag
# 0    5174
# 1    1869
# Name: count, dtype: int64

# %% [markdown]
# Split features

# %%
features = [
    "gender",
    "SeniorCitizen",
    "Partner",
    "Dependents",
    "tenure",
    "PhoneService",
    "MultipleLines",
    "InternetService",
    "OnlineSecurity",
    "OnlineBackup",
    "DeviceProtection",
    "TechSupport",
    "StreamingTV",
    "StreamingMovies",
    "Contract",
    "PaperlessBilling",
    "PaymentMethod",
    "MonthlyCharges",
    "TotalCharges",
    "ServiceCount"
]

target = "ChurnFlag"

X = df[features]
y = df[target]

# %%
categorical_features = [
    "gender",
    "Partner",
    "Dependents",
    "PhoneService",
    "MultipleLines",
    "InternetService",
    "OnlineSecurity",
    "OnlineBackup",
    "DeviceProtection",
    "TechSupport",
    "StreamingTV",
    "StreamingMovies",
    "Contract",
    "PaperlessBilling",
    "PaymentMethod"
]

# %%
numeric_features = [
    "SeniorCitizen",
    "tenure",
    "MonthlyCharges",
    "TotalCharges",
    "ServiceCount"
]

# %% [markdown]
# Split the data

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)
print("Training samples:", len(X_train))
print("Testing samples:", len(X_test))
# Out:
# Training samples: 5634
# Testing samples: 1409

# %% [markdown]
# Creating preprocessing pipeline

# %%
preprocessor = ColumnTransformer(
    transformers=[
        (
            "categorical",
            OneHotEncoder(handle_unknown="ignore"),
            categorical_features
        ),
        (
            "numerical",
            "passthrough",
            numeric_features
        )
    ]
)

# %% [markdown]
# Create the logistic regression model

# %%
model = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        (
            "classifier",
            LogisticRegression(max_iter=1000)
        )
    ]
)

# %% [markdown]
# Train the model

# %%
model.fit(X_train, y_train)
# Out:
# d:\VS CODE\Customer_churn_analytics\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:599: ConvergenceWarning: lbfgs failed to converge after 1000 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=1000).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('categorical',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['gender', 'Partner',
#                                                    'Dependents', 'PhoneService',
# ...

# %% [markdown]
# Model predictions

# %%
y_pred = model.predict(X_test)
print(y_pred)
# Out:
# [0 1 0 ... 0 0 0]

# %%
y_prob = model.predict_proba(X_test)[:, 1]
print(y_prob)
# Out:
# [0.04430742 0.68313474 0.06515979 ... 0.15741522 0.0038885  0.00612507]

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_prob)

print("Accuracy :", round(accuracy, 4))
print("Precision:", round(precision, 4))
print("Recall   :", round(recall, 4))
print("F1 Score :", round(f1, 4))
print("ROC-AUC  :", round(roc_auc, 4))
# Out:
# Accuracy : 0.8041
# Precision: 0.6531
# Recall   : 0.5588
# F1 Score : 0.6023
# ROC-AUC  : 0.8428

# %% [markdown]
# Accuracy
#
# How many predictions were correct overall.
#
# Correct predictions / Total predictions
# Precision
#
# Of the customers predicted to churn, how many actually churned?
#
# This matters when the company wants to avoid unnecessarily targeting customers who aren't likely to leave.
#
# Recall
#
# Of all customers who actually churned, how many did our model identify?
#
# For a churn-use case, recall can be particularly important because missing a potential churner means the company gets no opportunity to intervene.
#
# F1 Score
#
# Balance between precision and recall.
#
# ROC-AUC
#
# Measures how well the model separates churners from non-churners across classification thresholds.

# %% [markdown]
# Generating classification report

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.89      0.87      1035
#            1       0.65      0.56      0.60       374
#
#     accuracy                           0.80      1409
#    macro avg       0.75      0.73      0.74      1409
# weighted avg       0.80      0.80      0.80      1409

# %% [markdown]
# Generatinf confussion matrix

# %%
cm = confusion_matrix(y_test, y_pred)

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=["No Churn", "Churn"]
)

disp.plot()

plt.title("Confusion Matrix - Customer Churn")
plt.show()

# %% [markdown]
# Creating ROC curve

# %%
RocCurveDisplay.from_predictions(
    y_test,
    y_prob
)

plt.title("ROC Curve - Churn Prediction")
plt.show()

# %% [markdown]
# Creating churn probability for every customer

# %%
final_model = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        (
            "classifier",
            LogisticRegression(max_iter=1000)
        )
    ]
)

final_model.fit(X, y)
# Out:
# d:\VS CODE\Customer_churn_analytics\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:599: ConvergenceWarning: lbfgs failed to converge after 1000 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=1000).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('categorical',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['gender', 'Partner',
#                                                    'Dependents', 'PhoneService',
# ...

# %%
df["ChurnProbability"] = final_model.predict_proba(X)[:, 1]

# %%
df[
    [
        "customerID",
        "Churn",
        "ChurnProbability"
    ]
].head(10)
# Out:
#    customerID Churn  ChurnProbability
# 0  7590-VHVEG    No          0.637871
# 1  5575-GNVDE    No          0.043384
# 2  3668-QPYBK   Yes          0.290357
# 3  7795-CFOCW    No          0.030948
# 4  9237-HQITU   Yes          0.698559
# 5  9305-CDSKC   Yes          0.779074
# 6  1452-KIOVK    No          0.474916
# 7  6713-OKOMC    No          0.306332
# 8  7892-POOKP   Yes          0.601792
# 9  6388-TABGU    No          0.011383

# %% [markdown]
# Create risk level

# %%
df["RiskLevel"] = pd.cut(
    df["ChurnProbability"],
    bins=[0, 0.3, 0.7, 1],
    labels=["Low", "Medium", "High"],
    include_lowest=True
)

# %%
df[
    [
        "customerID",
        "ChurnProbability",
        "RiskLevel"
    ]
].head(20)
# Out:
#     customerID  ChurnProbability RiskLevel
# 0   7590-VHVEG          0.637871    Medium
# 1   5575-GNVDE          0.043384       Low
# 2   3668-QPYBK          0.290357       Low
# 3   7795-CFOCW          0.030948       Low
# 4   9237-HQITU          0.698559    Medium
# 5   9305-CDSKC          0.779074      High
# 6   1452-KIOVK          0.474916    Medium
# 7   6713-OKOMC          0.306332    Medium
# 8   7892-POOKP          0.601792    Medium
# 9   6388-TABGU          0.011383       Low
# 10  9763-GRSKD          0.204208       Low
# 11  7469-LKBCI          0.025161       Low
# 12  8091-TTVAX          0.171500       Low
# 13  0280-XJGEX          0.417969    Medium
# 14  5129-JLPIS          0.453600    Medium
# 15  3655-SNQYZ          0.032850       Low
# 16  8191-XWSZG          0.008603       Low
# 17  9959-WOFKT          0.046502       Low
# 18  4190-MFLUW          0.171479       Low
# 19  4183-MYFRB          0.555519    Medium

# %% [markdown]
# Check the number of customers in each risk category

# %%
df["RiskLevel"].value_counts()
# Out:
# RiskLevel
# Low       4374
# Medium    2221
# High       448
# Name: count, dtype: int64

# %%
df["RiskLevel"].value_counts().plot(
    kind="bar",
    title="Customer Churn Risk Distribution"
)

plt.xlabel("Risk Level")
plt.ylabel("Number of Customers")
plt.show()

# %% [markdown]
# Save the prediction dataset

# %%
output_columns = [
    "customerID",
    "gender",
    "SeniorCitizen",
    "Partner",
    "Dependents",
    "tenure",
    "Contract",
    "PaymentMethod",
    "InternetService",
    "MonthlyCharges",
    "TotalCharges",
    "Churn",
    "ChurnProbability",
    "RiskLevel"
]

final_df = df[output_columns]
final_df.to_csv(
    "../data/processed/customer_predictions.csv",
    index=False
)
